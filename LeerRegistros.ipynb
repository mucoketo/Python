# %%
# importamos el módulo que acabamos de crear

import runnersAverage

# %%
# llamamos a nuesra función y le pasamos el nombre del archivo
runnersAverage.data_runners('BHPOB - 1600m - 3000m obstáculos.csv')
# Out:
# ('BHPOB ',
#  ' 1600m ',
#  ' 3000m obstáculos',
#  4779.833333333333,
#  '0:47.8',
#  ['00:34.32', '00:58.43', '00:30.60', '00:19.06', '01:13.22', '01:11.16'])

# %%
# esto no devuelve una tupla, y nosotros ya sabemos como asignar estos datos a variables de forma rápida

data = runnersAverage.data_runners('BHPOB - 1600m - 3000m obstáculos.csv')

runner, meters, category, average_time, average_time_str, times = data

# también se puede hacer de otras maneras, imaginad que sólo queremos los times y el resto nos da igual
# metemos el resto en una variable y times en su propia varaible
*rest, times = data

print(rest, '\n' 'Aquí los tiempos: ', times)
# Out:
# ['BHPOB ', ' 1600m ', ' 3000m obstáculos', 4779.833333333333, '0:47.8']
# Aquí los tiempos:  ['00:34.32', '00:58.43', '00:30.60', '00:19.06', '01:13.22', '01:11.16']

# %%
# Ahora vamos a hacer una lista con los nombres de los archivos, para ello lo primero que debemos importar es la
# librería os
import os

# %%
runners_files = os.listdir(runnersAverage.FOLDER)

print(runners_files)
# Out:
# ['FKOQO - 110m - 200m lisos.csv', 'GTATE - 1600m - 100m lisos.csv', 'CGQJQ - 800m - 3000m obstáculos.csv', 'EVWTX - 1600m - 1500m lisos.csv', 'WGSLN - 3000m - 4x100m relevo.csv', 'GKQGV - 400m - 800m lisos.csv', 'IBSJS - 1600m - 100m lisos.csv', 'HEXGZ - 400m - 200m lisos.csv', 'GLGOK - 200m - 800m lisos.csv', 'OMSEE - 800m - 1500m lisos.csv', 'MDAEC - 1600m - 1500m lisos.csv', 'QJDIX - 110m - 400m vallas.csv', 'EKZFR - 400m - 4x100m relevo.csv', 'SVNJW - 110m - 400m lisos.csv', 'EUIMZ - 400m - 110m vallas.csv', 'RINGT - 400m - 400m lisos.csv', 'BHPOB - 1600m - 3000m obstáculos.csv', 'CJXTQ - 1500m - 400m vallas.csv', 'BXWXM - 110m - 4x400m relevo.csv', 'ZZHXX - 400m - 4x400m relevo.csv', 'TNAZJ - 400m - 1500m lisos.csv', 'SLERZ - 110m - 400m lisos.csv', 'BWEUR - 1600m - 200m lisos.csv', 'OLDQS - 100m - 4x100m relevo.csv', 'QWCKE - 800m - 1500m lisos.csv', 'CLRPY - 1500m - 1500m lisos.csv', 'DZPAM - 400m - 100m lisos.csv', 'JXJZV - 400m - 4x100m relevo.csv', 'KAJNJ - 400m - 110m vall
# ...

# %%
len(runners_files)
# Out:
# 50

# %%
# hagamos un bucle
for f in runners_files:
    print(runnersAverage.data_runners(f))
# Out:
# ('FKOQO ', ' 110m ', ' 200m lisos', 6508.5, '1:5.08', ['01:04.32', '01:17.53', '01:46.42', '00:40.00', '01:04.80', '00:37.44'])
# ('GTATE ', ' 1600m ', ' 100m lisos', 3241.6666666666665, '0:32.42', ['00:08.46', '00:40.15', '00:34.10', '00:20.70', '00:54.69', '00:36.40'])
# ('CGQJQ ', ' 800m ', ' 3000m obstáculos', 7092.666666666667, '1:10.93', ['00:46.59', '01:00.46', '01:33.23', '01:46.91', '00:30.69', '01:27.68'])
# ('EVWTX ', ' 1600m ', ' 1500m lisos', 4155.666666666667, '0:41.56', ['01:30.75', '01:31.29', '00:06.24', '00:16.47', '00:08.64', '00:35.95'])
# ('WGSLN ', ' 3000m ', ' 4x100m relevo', 7826, '1:18.26', ['00:41.56', '01:11.49', '01:17.88', '01:11.82', '01:42.20', '01:44.61'])
# ('GKQGV ', ' 400m ', ' 800m lisos', 6241.666666666667, '1:2.42', ['00:00.99', '00:11.25', '01:21.60', '01:45.91', '01:59.80', '00:54.95'])
# ('IBSJS ', ' 1600m ', ' 100m lisos', 5983.666666666667, '0:59.84', ['01:15.78', '00:24.19', '00:29.35', '00:37.49', '01:44.92', '01:27.29'])
# ...
